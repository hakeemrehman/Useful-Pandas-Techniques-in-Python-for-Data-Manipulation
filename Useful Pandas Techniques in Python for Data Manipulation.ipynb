# %% [markdown]
# ## Useful Pandas Techniques in Python for Data Manipulation
#
# #### 1) Subsetting the Dataframe in Pandas
# #### 2) Groupby Function and Pivot Table in Pandas
# #### 3) Concatenate (Assemble) Pandas DataFrames
# #### 4) Use of Apply Function in Pandas
# #### 5)  Dealing with the missing values using Pandas
# #### 6) Plotting (Boxplot & Histogram) with Pandas

# %% [markdown]
# ### Loading data

# %%
# load the Pandas library
# Method-1
import pandas

# %%
# Method-2
from pandas import *

# %%
# Read/Load the data: '.csv file' (comma-separated values file)
pandas.read_csv('D:/Python Practice/1. Data Manipulation & Analysis Using Python (Pandad & Matlibplot)/BikeStoresales_data.csv')
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       11/26/2013   26  November  2013            19     Youth (<25)
# 1       11/26/2015   26  November  2015            19     Youth (<25)
# 2        3/23/2014   23     March  2014            49  Adults (35-64)
# 3        3/23/2016   23     March  2016            49  Adults (35-64)
# 4        5/15/2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031   4/12/2016   12     April  2016            41  Adults (35-64)
# 113032    4/2/2014    2     April  2014            18     Youth (<25)
# 113033    4/2/2016    2     April  2016            18     Youth (<25)
# 113034    3/4/2014    4     March  2014            37  Adults (35-64)
# 113035    3/4/2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
# import with an alias
import pandas as pd

# %%
sales = pd.read_csv('D:/Python Practice/1. Data Manipulation & Analysis Using Python (Pandad & Matlibplot)/BikeStoresales_data.csv')

# %% [markdown]
# ### 1: Subsetting the Dataframe in Pandas

# %%
# Get the under 25 age customers sales data of the 'United States' 

# Method-1
sales.loc[(sales.Country == 'United States') & (sales.Age_Group == 'Youth (<25)')]
# Out:
#               Date  Day      Month  Year  Customer_Age    Age_Group  \
# 56      12/31/2013   31   December  2013            23  Youth (<25)
# 57      12/31/2015   31   December  2015            23  Youth (<25)
# 122      5/10/2014   10        May  2014            22  Youth (<25)
# 123      5/10/2016   10        May  2016            22  Youth (<25)
# 152     12/31/2013   31   December  2013            24  Youth (<25)
# ...            ...  ...        ...   ...           ...          ...
# 113013   9/16/2015   16  September  2015            20  Youth (<25)
# 113014  12/10/2013   10   December  2013            20  Youth (<25)
# 113015  12/10/2015   10   December  2015            20  Youth (<25)
# 113016   10/4/2013    4    October  2013            20  Youth (<25)
# 113017   10/4/2015    4    October  2015            20  Youth (<25)
#
#        Customer_Gender        Country       State Product_Category  \
# 56                   M  United States  California      Accessories
# ...

# %%
# For instance, we want a list of all females who are from the Adults(35-64) age_group and bought a Hitch Rack - 4-Bike product.
(sales.loc[(sales["Customer_Gender"]=="F") & (sales["Age_Group"]=="Adults (35-64)") & (sales["Product"]=="Hitch Rack - 4-Bike"),
          ["Customer_Gender","Age_Group","Product"]])
# Out:
#     Customer_Gender       Age_Group              Product
# 4                 F  Adults (35-64)  Hitch Rack - 4-Bike
# 5                 F  Adults (35-64)  Hitch Rack - 4-Bike
# 6                 F  Adults (35-64)  Hitch Rack - 4-Bike
# 7                 F  Adults (35-64)  Hitch Rack - 4-Bike
# 28                F  Adults (35-64)  Hitch Rack - 4-Bike
# ..              ...             ...                  ...
# 557               F  Adults (35-64)  Hitch Rack - 4-Bike
# 564               F  Adults (35-64)  Hitch Rack - 4-Bike
# 565               F  Adults (35-64)  Hitch Rack - 4-Bike
# 566               F  Adults (35-64)  Hitch Rack - 4-Bike
# 567               F  Adults (35-64)  Hitch Rack - 4-Bike
#
# [146 rows x 3 columns]

# %%
# Select all data entries against which profit is greater than mean (average) value
profit_mean = sales.Profit.mean()
sales.loc[sales['Profit'] > profit_mean]
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0       11/26/2013   26  November  2013            19           Youth (<25)
# 1       11/26/2015   26  November  2015            19           Youth (<25)
# 2        3/23/2014   23     March  2014            49        Adults (35-64)
# 3        3/23/2016   23     March  2016            49        Adults (35-64)
# 5        5/15/2016   15       May  2016            47        Adults (35-64)
# ...            ...  ...       ...   ...           ...                   ...
# 113027    7/8/2015    8      July  2015            29  Young Adults (25-34)
# 113032    4/2/2014    2     April  2014            18           Youth (<25)
# 113033    4/2/2016    2     April  2016            18           Youth (<25)
# 113034    3/4/2014    4     March  2014            37        Adults (35-64)
# 113035    3/4/2016    4     March  2016            37        Adults (35-64)
#
# ...

# %%
# Select 'Customer_Gender, Age_Group and Product' data entries against which profit is greater than mean (average) value
profit_mean = sales.Profit.mean()
sales.loc[sales['Profit'] > profit_mean, ["Customer_Gender","Age_Group","Product"]]
# Out:
#        Customer_Gender             Age_Group              Product
# 0                    M           Youth (<25)  Hitch Rack - 4-Bike
# 1                    M           Youth (<25)  Hitch Rack - 4-Bike
# 2                    M        Adults (35-64)  Hitch Rack - 4-Bike
# 3                    M        Adults (35-64)  Hitch Rack - 4-Bike
# 5                    F        Adults (35-64)  Hitch Rack - 4-Bike
# ...                ...                   ...                  ...
# 113027               M  Young Adults (25-34)      Classic Vest, L
# 113032               M           Youth (<25)      Classic Vest, M
# 113033               M           Youth (<25)      Classic Vest, M
# 113034               F        Adults (35-64)      Classic Vest, L
# 113035               F        Adults (35-64)      Classic Vest, L
#
# [34088 rows x 3 columns]

# %%
# Method-2
#':' in python means give me all the columns
sales.loc[(sales.Country == 'United States') & (sales.Age_Group == 'Youth (<25)'), :]
# Out:
#               Date  Day      Month  Year  Customer_Age    Age_Group  \
# 56      12/31/2013   31   December  2013            23  Youth (<25)
# 57      12/31/2015   31   December  2015            23  Youth (<25)
# 122      5/10/2014   10        May  2014            22  Youth (<25)
# 123      5/10/2016   10        May  2016            22  Youth (<25)
# 152     12/31/2013   31   December  2013            24  Youth (<25)
# ...            ...  ...        ...   ...           ...          ...
# 113013   9/16/2015   16  September  2015            20  Youth (<25)
# 113014  12/10/2013   10   December  2013            20  Youth (<25)
# 113015  12/10/2015   10   December  2015            20  Youth (<25)
# 113016   10/4/2013    4    October  2013            20  Youth (<25)
# 113017   10/4/2015    4    October  2015            20  Youth (<25)
#
#        Customer_Gender        Country       State Product_Category  \
# 56                   M  United States  California      Accessories
# ...

# %% [markdown]
# ### 2. Groupby Function and Pivot Table in Pandas

# %% [markdown]
# #### Groupby Function

# %%
# How many time each particulcar country value repeated in data?
sales.groupby('Country').count()
# Out:
#                  Date    Day  Month   Year  Customer_Age  Age_Group  \
# Country
# Australia       23936  23936  23936  23936         23936      23936
# Canada          14178  14178  14178  14178         14178      14178
# France          10998  10998  10998  10998         10998      10998
# Germany         11098  11098  11098  11098         11098      11098
# United Kingdom  13620  13620  13620  13620         13620      13620
# United States   39206  39206  39206  39206         39206      39206
#
#                 Customer_Gender  State  Product_Category  Sub_Category  \
# Country
# Australia                 23936  23936             23936         23936
# Canada                    14178  14178             14178         14178
# France                    10998  10998             10998         10998
# Germany                   11098  11098             11098         11098
# United Kingdom            13620  13620             13620         13620
# ...

# %%
# How many time each particulcar country value repeated in data?
sales.groupby('Country')['Country'].count()
# Out:
# Country
# Australia         23936
# Canada            14178
# France            10998
# Germany           11098
# United Kingdom    13620
# United States     39206
# Name: Country, dtype: int64

# %%
# How many time country + Age_Group wise values repeated in data?
sales.groupby(['Country', 'Age_Group'])['Country'].count()
# Out:
# Country         Age_Group
# Australia       Adults (35-64)          10394
#                 Seniors (64+)              58
#                 Young Adults (25-34)     9102
#                 Youth (<25)              4382
# Canada          Adults (35-64)           7158
#                 Seniors (64+)             116
#                 Young Adults (25-34)     4578
#                 Youth (<25)              2326
# France          Adults (35-64)           4786
#                 Seniors (64+)              70
#                 Young Adults (25-34)     4552
#                 Youth (<25)              1590
# Germany         Adults (35-64)           4868
#                 Seniors (64+)             106
#                 Young Adults (25-34)     4416
#                 Youth (<25)              1708
# United Kingdom  Adults (35-64)           6658
#                 Seniors (64+)             102
#                 Young Adults (25-34)     4736
#                 Youth (<25)              2124
# ...

# %%
sales.groupby(['Country', 'Age_Group'])['Country'].count().unstack()
# Out:
# Age_Group       Adults (35-64)  Seniors (64+)  Young Adults (25-34)  \
# Country
# Australia                10394             58                  9102
# Canada                    7158            116                  4578
# France                    4786             70                  4552
# Germany                   4868            106                  4416
# United Kingdom            6658            102                  4736
# United States            21960            278                 11270
#
# Age_Group       Youth (<25)
# Country
# Australia              4382
# Canada                 2326
# France                 1590
# Germany                1708
# United Kingdom         2124
# United States          5698

# %% [markdown]
# #### Groupby Function + Descriptive Analysis

# %%
# Computing average profit country wise
sales.groupby('Country')['Profit'].mean()
# Out:
# Country
# Australia         283.089489
# Canada            262.187615
# France            261.891435
# Germany           302.756803
# United Kingdom    324.071439
# United States     282.447687
# Name: Profit, dtype: float64

# %%
# Computing average of Profit and ordered quntity in particular month
sales.groupby('Month')[['Profit','Order_Quantity']].mean()
# Out:
#                Profit  Order_Quantity
# Month
# April      281.351306       11.634944
# August     270.024878       12.575488
# December   304.438571       11.902857
# February   284.008202       11.606850
# January    282.046639       11.887872
# July       286.752881       12.032565
# June       301.191294       11.446591
# March      285.493694       11.482841
# May        298.969896       11.297178
# November   273.472979       12.438402
# October    263.007086       12.382629
# September  275.491183       12.634215

# %%
# Computing average of Profit and ordered quntity in particular month and Age_group wise
sales.groupby(['Month','Age_Group'])[['Profit','Order_Quantity']].mean()
# Out:
#                                     Profit  Order_Quantity
# Month     Age_Group
# April     Adults (35-64)        278.430438       12.161467
#           Seniors (64+)         223.767442       13.802326
#           Young Adults (25-34)  307.865993       11.173665
#           Youth (<25)           225.471218       11.029451
# August    Adults (35-64)        260.944324       12.985405
#           Seniors (64+)          76.500000       15.840000
#           Young Adults (25-34)  289.431507       11.940313
#           Youth (<25)           258.300578       12.768786
# December  Adults (35-64)        310.091052       11.763106
#           Seniors (64+)         292.065217       12.760870
#           Young Adults (25-34)  311.425417       11.822130
#           Youth (<25)           276.200100       12.401198
# February  Adults (35-64)        298.405308       11.852442
#           Seniors (64+)         192.145833       14.416667
#           Young Adults (25-34)  289.164923       11.211994
# ...

# %%
# Use Groupby() function to calculate the AGe_group wise Descriptive Analysis of a qualitative variable

# Method-1
sales.groupby(['Age_Group'])['Month'].describe()
# Out:
#                       count unique       top  freq
# Age_Group
# Adults (35-64)        55824     12      June  6038
# Seniors (64+)           730     12      June    94
# Young Adults (25-34)  38654     12  December  4076
# Youth (<25)           17828     12  December  2004

# %%
# Method-2
sales[['Month','Age_Group']].groupby('Age_Group').describe()
# Out:
#                       Month
#                       count unique       top  freq
# Age_Group
# Adults (35-64)        55824     12      June  6038
# Seniors (64+)           730     12      June    94
# Young Adults (25-34)  38654     12  December  4076
# Youth (<25)           17828     12  December  2004

# %%
# Calculate the AGe_group wise Descriptive Analysis of the Unit_Cost and Profit Variables (Quantitative Variables)
sales[['Age_Group','Unit_Cost','Profit']].groupby('Age_Group').describe()
# Out:
#                      Unit_Cost                                                \
#                          count        mean         std  min  25%  50%    75%
# Age_Group
# Adults (35-64)         55824.0  268.299369  550.310977  1.0  2.0  9.0   42.0
# Seniors (64+)            730.0   88.695890  308.319189  1.0  2.0  8.0   13.0
# Young Adults (25-34)   38654.0  289.403374  564.628414  1.0  2.0  9.0  295.0
# Youth (<25)            17828.0  223.537245  518.823165  1.0  2.0  8.0   26.0
#
#                                Profit                                      \
#                          max    count        mean         std   min   25%
# Age_Group
# Adults (35-64)        2171.0  55824.0  292.375717  459.192217 -24.0  30.0
# Seniors (64+)         2171.0    730.0  189.267123  343.051466   0.0  23.0
# Young Adults (25-34)  2171.0  38654.0  294.581699  458.898770 -30.0  32.0
# Youth (<25)           2171.0  17828.0  245.377608  426.919648 -16.0  22.0
#
#
# ...

# %%
em = sales.groupby(['Country', 'Age_Group'])['Country'].count().unstack().plot(kind='bar', stacked=False, figsize=(14,6))
em.set_ylabel('Number of Customers')
em.set_xlabel('Country')
# Out:
# Text(0.5, 0, 'Country')

# %%
sal = sales.groupby(['Country', 'Age_Group']).size().unstack().plot(kind='bar', stacked=True, figsize=(14,6))
sal.set_ylabel('Number of Customers')
# Out:
# Text(0, 0.5, 'Number of Customers')

# %% [markdown]
# #### Pivot Table
# - Pandas can be used to create MS Excel style pivot tables.

# %%
# Compute the Mean w.r.t Age_Group wise
pd.pivot_table(sales,index=["Age_Group"])
# Out:
#                             Cost  Customer_Age        Day  Order_Quantity  \
# Age_Group
# Adults (35-64)        470.453049     44.491473  15.566781       12.045303
# Seniors (64+)         232.708219     70.210959  15.627397       13.530137
# Young Adults (25-34)  498.495705     29.750246  15.689967       11.560899
# Youth (<25)           412.194694     21.048463  15.924725       12.124018
#
#                           Profit     Revenue   Unit_Cost  Unit_Price  \
# Age_Group
# Adults (35-64)        292.375717  762.828765  268.299369  455.185046
# Seniors (64+)         189.267123  421.975342   88.695890  156.260274
# Young Adults (25-34)  294.581699  793.077405  289.403374  489.569928
# Youth (<25)           245.377608  657.572302  223.537245  378.628674
#
#                              Year
# Age_Group
# Adults (35-64)        2014.446098
# Seniors (64+)         2014.573973
# Young Adults (25-34)  2014.369069
# Youth (<25)           2014.326621

# %%
sales.groupby('Age_Group').mean()
# Out:
#                             Day         Year  Customer_Age  Order_Quantity  \
# Age_Group
# Adults (35-64)        15.566781  2014.446098     44.491473       12.045303
# Seniors (64+)         15.627397  2014.573973     70.210959       13.530137
# Young Adults (25-34)  15.689967  2014.369069     29.750246       11.560899
# Youth (<25)           15.924725  2014.326621     21.048463       12.124018
#
#                        Unit_Cost  Unit_Price      Profit        Cost  \
# Age_Group
# Adults (35-64)        268.299369  455.185046  292.375717  470.453049
# Seniors (64+)          88.695890  156.260274  189.267123  232.708219
# Young Adults (25-34)  289.403374  489.569928  294.581699  498.495705
# Youth (<25)           223.537245  378.628674  245.377608  412.194694
#
#                          Revenue
# Age_Group
# Adults (35-64)        762.828765
# Seniors (64+)         421.975342
# Young Adults (25-34)  793.077405
# Youth (<25)           657.572302

# %%
pd.pivot_table(sales,index=["Country","Age_Group"])
# Out:
#                                            Cost  Customer_Age        Day  \
# Country        Age_Group
# Australia      Adults (35-64)        610.589475     43.951895  15.490475
#                Seniors (64+)         640.172414     66.724138  17.586207
#                Young Adults (25-34)  592.215337     29.711492  16.065920
#                Youth (<25)           628.043816     20.966225  15.522592
# Canada         Adults (35-64)        324.528919     44.653255  15.243085
#                Seniors (64+)         150.500000     67.793103  16.620690
#                Young Adults (25-34)  291.562254     30.087811  15.720402
#                Youth (<25)           233.548581     20.877902  15.809114
# France         Adults (35-64)        489.967196     44.436272  15.584204
#                Seniors (64+)         119.642857     74.914286  15.600000
#                Young Adults (25-34)  564.197496     29.521968  15.587873
# ...

# %%
pd.pivot_table(sales,index=["Country"],values=(["Profit","Unit_Cost"]))
# Out:
#                     Profit   Unit_Cost
# Country
# Australia       283.089489  364.062834
# Canada          262.187615  133.626605
# France          261.891435  292.174941
# Germany         302.756803  300.882682
# United Kingdom  324.071439  269.370925
# United States   282.447687  239.350559

# %% [markdown]
# #### Pivot Table + Descriptive Analysis

# %%
import numpy as np
pd.pivot_table(sales,index=["Country"],values=(["Unit_Cost","Profit"]), aggfunc=[np.mean,np.median,np.std])
# Out:
#                       mean             median                   std  \
#                     Profit   Unit_Cost Profit Unit_Cost      Profit
# Country
# Australia       283.089489  364.062834    114        13  430.600293
# Canada          262.187615  133.626605     83         7  451.913361
# France          261.891435  292.174941     99        11  407.551064
# Germany         302.756803  300.882682    134        11  451.431208
# United Kingdom  324.071439  269.370925    134         9  483.800008
# United States   282.447687  239.350559     87         8  469.443771
#
#
#                  Unit_Cost
# Country
# Australia       642.095449
# Canada          408.005168
# France          557.954144
# Germany         552.461887
# United Kingdom  520.000418
# United States   527.862212

# %%
pd.pivot_table(sales,index=["Country","Age_Group"],values=(["Unit_Cost","Profit"]), aggfunc=[np.mean,np.median,np.std])
# Out:
#                                            mean             median            \
#                                          Profit   Unit_Cost Profit Unit_Cost
# Country        Age_Group
# Australia      Adults (35-64)        284.241678  366.218588  128.0      13.0
#                Seniors (64+)         308.982759  364.862069  212.5      13.0
#                Young Adults (25-34)  277.845748  351.145902   91.0       9.0
#                Youth (<25)           290.905751  385.769055  103.0      13.0
# Canada         Adults (35-64)        291.496228  148.436155  124.0       9.0
#                Seniors (64+)         199.344828   30.155172  118.0       8.5
#                Young Adults (25-34)  249.368065  132.672783   71.0       3.0
#                Youth (<25)           200.358985   95.089424   47.0       2.0
# France         Adults (35-64)        266.730255  292.709570   91.5       9.0
#                Seniors (64+)          80.057143    8.285714   24.5       2.0
# ...

# %%
ptable = pd.pivot_table(sales,index=["Country","Age_Group"],values=["Profit","Unit_Cost"],
               aggfunc={"Profit":[np.sum],"Unit_Cost":[np.sum,np.mean]}) # list of aggfunctions to apply to each value
ptable
# Out:
#                                       Profit   Unit_Cost
#                                          sum        mean        sum
# Country        Age_Group
# Australia      Adults (35-64)        2954408  366.218588  3806476.0
#                Seniors (64+)           17921  364.862069    21162.0
#                Young Adults (25-34)  2528952  351.145902  3196130.0
#                Youth (<25)           1274749  385.769055  1690440.0
# Canada         Adults (35-64)        2086530  148.436155  1062506.0
#                Seniors (64+)           23124   30.155172     3498.0
#                Young Adults (25-34)  1141607  132.672783   607376.0
#                Youth (<25)            466035   95.089424   221178.0
# France         Adults (35-64)        1276571  292.709570  1400908.0
#                Seniors (64+)            5604    8.285714      580.0
#                Young Adults (25-34)  1245645  332.378295  1512986.0
#                Youth (<25)            352462  187.966038   298866.0
# ...

# %%
# Pivot Table Filtering
ptable.query('Country == ["United States"]')
# Out:
#                                      Profit   Unit_Cost
#                                         sum        mean        sum
# Country       Age_Group
# United States Adults (35-64)        6294445  244.508379  5369404.0
#               Seniors (64+)           56687  118.467626    32934.0
#               Young Adults (25-34)  3511676  275.685714  3106978.0
#               Youth (<25)           1210836  153.503335   874662.0

# %%
ptable.query('Country == ["United States","Germany"]')
# Out:
#                                      Profit   Unit_Cost
#                                         sum        mean        sum
# Country       Age_Group
# Germany       Adults (35-64)        1532084  319.874281  1557148.0
#               Seniors (64+)           15037   17.150943     1818.0
#               Young Adults (25-34)  1377591  316.625453  1398218.0
#               Youth (<25)            435283  223.660422   382012.0
# United States Adults (35-64)        6294445  244.508379  5369404.0
#               Seniors (64+)           56687  118.467626    32934.0
#               Young Adults (25-34)  3511676  275.685714  3106978.0
#               Youth (<25)           1210836  153.503335   874662.0

# %% [markdown]
# #### Pandas performance: pivot_table vs groupby

# %%
# %time pd.pivot_table(sales,index=["Age_Group"])
# Out:
# Wall time: 52.5 ms
#                             Cost  Customer_Age        Day  Order_Quantity  \
# Age_Group
# Adults (35-64)        470.453049     44.491473  15.566781       12.045303
# Seniors (64+)         232.708219     70.210959  15.627397       13.530137
# Young Adults (25-34)  498.495705     29.750246  15.689967       11.560899
# Youth (<25)           412.194694     21.048463  15.924725       12.124018
#
#                           Profit     Revenue   Unit_Cost  Unit_Price  \
# Age_Group
# Adults (35-64)        292.375717  762.828765  268.299369  455.185046
# Seniors (64+)         189.267123  421.975342   88.695890  156.260274
# Young Adults (25-34)  294.581699  793.077405  289.403374  489.569928
# Youth (<25)           245.377608  657.572302  223.537245  378.628674
#
#                              Year
# Age_Group
# Adults (35-64)        2014.446098
# Seniors (64+)         2014.573973
# Young Adults (25-34)  2014.369069
# Youth (<25)           2014.326621

# %%
# %time sales.groupby('Age_Group').mean()
# Out:
# Wall time: 46.1 ms
#                             Day         Year  Customer_Age  Order_Quantity  \
# Age_Group
# Adults (35-64)        15.566781  2014.446098     44.491473       12.045303
# Seniors (64+)         15.627397  2014.573973     70.210959       13.530137
# Young Adults (25-34)  15.689967  2014.369069     29.750246       11.560899
# Youth (<25)           15.924725  2014.326621     21.048463       12.124018
#
#                        Unit_Cost  Unit_Price      Profit        Cost  \
# Age_Group
# Adults (35-64)        268.299369  455.185046  292.375717  470.453049
# Seniors (64+)          88.695890  156.260274  189.267123  232.708219
# Young Adults (25-34)  289.403374  489.569928  294.581699  498.495705
# Youth (<25)           223.537245  378.628674  245.377608  412.194694
#
#                          Revenue
# Age_Group
# Adults (35-64)        762.828765
# Seniors (64+)         421.975342
# Young Adults (25-34)  793.077405
# Youth (<25)           657.572302

# %% [markdown]
# ### 3. Concatenate (Assemble) Pandas DataFrames

# %%
df_1 = pd.read_csv('D:/Python Practice/1. Data Manipulation & Analysis Using Python (Pandad & Matlibplot)/data/Assemble_1.csv')
df_2 = pd.read_csv('D:/Python Practice/1. Data Manipulation & Analysis Using Python (Pandad & Matlibplot)/data/Assemble_2.csv')

# %%
df_1
# Out:
#     A    B     C      D
# 0  10  100  1000  10000
# 1  20  200  2000  20000
# 2  30  300  3000  30000
# 3  40  400  4000  40000
# 4  50  500  5000  50000

# %%
df_2
# Out:
#      A     B      C       D
# 0   60   600   6000   60000
# 1   70   700   7000   70000
# 2   80   800   8000   80000
# 3   90   900   9000   90000
# 4  100  1000  10000  100000
# 5  110  1100  11000  110000

# %% [markdown]
# #### Assemble (Concatenate) Data Row wise

# %%
row_assemble = pd.concat([df_1, df_2])

# %%
row_assemble
# Out:
#      A     B      C       D
# 0   10   100   1000   10000
# 1   20   200   2000   20000
# 2   30   300   3000   30000
# 3   40   400   4000   40000
# 4   50   500   5000   50000
# 0   60   600   6000   60000
# 1   70   700   7000   70000
# 2   80   800   8000   80000
# 3   90   900   9000   90000
# 4  100  1000  10000  100000
# 5  110  1100  11000  110000

# %%
# Select all the rows with 'Zero' index rows
row_assemble.loc[0]
# Out:
#     A    B     C      D
# 0  10  100  1000  10000
# 0  60  600  6000  60000

# %%
# Select the first row only - use 'iloc'
row_assemble.iloc[0]
# Out:
# A       10
# B      100
# C     1000
# D    10000
# Name: 0, dtype: int64

# %% [markdown]
# #### Assemble (Concatenate) Data Column wise

# %%
# Use Concat function but with additional artibute 'axis=1'
col_assemble = pd.concat([df_1, df_2], axis=1)
col_assemble
# Out:
#       A      B       C        D    A     B      C       D
# 0  10.0  100.0  1000.0  10000.0   60   600   6000   60000
# 1  20.0  200.0  2000.0  20000.0   70   700   7000   70000
# 2  30.0  300.0  3000.0  30000.0   80   800   8000   80000
# 3  40.0  400.0  4000.0  40000.0   90   900   9000   90000
# 4  50.0  500.0  5000.0  50000.0  100  1000  10000  100000
# 5   NaN    NaN     NaN      NaN  110  1100  11000  110000

# %%
col_assemble['A']
# Out:
#       A    A
# 0  10.0   60
# 1  20.0   70
# 2  30.0   80
# 3  40.0   90
# 4  50.0  100
# 5   NaN  110

# %% [markdown]
# ### 4. Use of Apply Function in Pandas
# - Pandas Apply function returns some value after passing each row/column of a data frame with some function. The function can be both default or user-defined.
# - For the data manipulation and cleaning we might want to do some complex calculation with the data for that we may need to define functions etc.

# %%
# How to write a function in Python?

# squares a given value
def square(x):
    return x ** 2

# %%
square(2)
# Out:
# 4

# %%
square(5)
# Out:
# 25

# %%
# calculates avgerage of two given numbers
def Avg(x, y):
    return (x + y) / 2.0

# %%
Avg(5,6)
# Out:
# 5.5

# %%
df = pd.DataFrame({
    'a': [5, 10 , 15],
    'b': [10 , 20, 30]
})
df
# Out:
#     a   b
# 0   5  10
# 1  10  20
# 2  15  30

# %%
# Take the Square of the first column 
df['a'] ** 2
# Similar thing can be down use 'apply' function
# Out:
# 0     25
# 1    100
# 2    225
# Name: a, dtype: int64

# %%
# Pass our defined function to 'apply' function 
df['a'].apply(square)
# Out:
# 0     25
# 1    100
# 2    225
# Name: a, dtype: int64

# %%
# Creat a function that just print nothing else
def print_it(a):
    print(a)

# %%
df
# Out:
#     a   b
# 0   5  10
# 1  10  20
# 2  15  30

# %%
# Here we use the apply function and passes the our own defined function
# So, it will print the values column wise
# In the last part of the output we saw None, None... because our defined function return nothing 
df.apply(print_it)
# Out:
# 0     5
# 1    10
# 2    15
# Name: a, dtype: int64
# 0    10
# 1    20
# 2    30
# Name: b, dtype: int64
# a    None
# b    None
# dtype: object

# %%
def Avg3(x, y, z):
    return (x + y + z) / 3

# %%
# Compute the average column wise of the above dataframe 
# ------------------------------------------------------

# When we use the apply function here it will give the error
# because 'apply' function only pick the first column of the data in this way
df.apply(Avg3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-12d4a174cf97> in <module>
#       4 # When we use the apply function here it will give the error
#       5 # because 'apply' function only pick the first column of the data in this way
# ----> 6 df.apply(Avg3)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     294             try:
# ...

# %%
# To deal with this issue, we need to define our function as follows:
def Avg3(col):
    x = col[0]
    y = col[1]
    z = col[2]
    return (x + y + z) / 3

# %%
df.apply(Avg3)
# Out:
# a    10.0
# b    20.0
# dtype: float64

# %%
# Compute the average row wise of the above dataframe 
# ---------------------------------------------------
def Avg2(row):
    x = row[0]
    y = row[1]
    return (x + y) / 2
df.apply(Avg2, axis=1)
# Out:
# 0     7.5
# 1    15.0
# 2    22.5
# dtype: float64

# %%
# World COVID 19 Data Set
# save to a variable
worldmeter = pd.read_csv('D:/1. Python Practice/1. Data Manipulation & Analysis Using Python (Pandad & Matlibplot)/worldometer_data.csv')

# %%
worldmeter.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.310764e+08     3545077       NaN
# 1         Brazil  South America  2.126159e+08     1931204       NaN
# 2          India           Asia  1.380493e+09      937844     357.0
# 3         Russia         Europe  1.459370e+08      739947       NaN
# 4           Peru  South America  3.298745e+07      333867       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     139143.0        NaN       1600195.0           NaN    1805739.0
# 1      74262.0        NaN       1213512.0           NaN     643430.0
# 2      24327.0       12.0        593178.0          98.0     320339.0
# 3      11614.0        NaN        512825.0           NaN     215508.0
# 4      12229.0        NaN        223261.0           NaN      98377.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           16337.0           10708.0          420.0  44030877.0
# ...

# %%
#Create a new function:
def missing_number(a):
  return sum(a.isnull())

#Applying per column:
print ("Missing values per column: ")
print (worldmeter.apply(missing_number, axis=0)) # axis=0 defines that function is to be applied on each column
# Out:
# Missing values per column:
# Country/Region        0
# Continent             2
# Population            2
# TotalCases            0
# NewCases            187
# TotalDeaths          24
# NewDeaths           198
# TotalRecovered        5
# NewRecovered        190
# ActiveCases           4
# Serious,Critical     80
# Tot Cases/1M pop      2
# Deaths/1M pop        26
# TotalTests           20
# Tests/1M pop         20
# WHO Region           25
# dtype: int64

# %%
#Applying per row:
print ("Missing values per row: ")
print (worldmeter.apply(missing_number, axis=1)) #axis=1 defines that function is to be applied on each row
# Out:
# Missing values per row:
# 0       3
# 1       3
# 2       0
# 3       3
# 4       3
#        ..
# 204     5
# 205     8
# 206     6
# 207     6
# 208    12
# Length: 209, dtype: int64

# %% [markdown]
# ### 5. Dealing with the missing values using Pandas
#
# - 'fillna()’ does it in one go.

# %%
#First we import scipy function to determine the mode
from scipy.stats import mode
mode(worldmeter['WHO Region'])
# Out:
# ModeResult(mode=array(['Europe'], dtype=object), count=array([55]))

# %%
mode(worldmeter['WHO Region']).mode[0]
# Out:
# 'Europe'

# %%
#Impute the values:
worldmeter['WHO Region'].fillna(mode(worldmeter['WHO Region']).mode[0], inplace=True)
worldmeter['Continent'].fillna(mode(worldmeter['Continent']).mode[0], inplace=True)

#Now check the #missing values again to confirm:
print (worldmeter.apply(missing_number, axis=0))
# Out:
# Country/Region        0
# Continent             0
# Population            2
# TotalCases            0
# NewCases            187
# TotalDeaths          24
# NewDeaths           198
# TotalRecovered        5
# NewRecovered        190
# ActiveCases           4
# Serious,Critical     80
# Tot Cases/1M pop      2
# Deaths/1M pop        26
# TotalTests           20
# Tests/1M pop         20
# WHO Region            0
# dtype: int64

# %%
import numpy as np
np.mean(worldmeter['Population'])
# Out:
# 30539551.512077294

# %%
worldmeter['Population'].fillna(np.mean(worldmeter['Population']), inplace=True)

#Now check the #missing values again to confirm:
print (worldmeter.apply(missing_number, axis=0))
# Out:
# Country/Region        0
# Continent             0
# Population            0
# TotalCases            0
# NewCases            187
# TotalDeaths          24
# NewDeaths           198
# TotalRecovered        5
# NewRecovered        190
# ActiveCases           4
# Serious,Critical     80
# Tot Cases/1M pop      2
# Deaths/1M pop        26
# TotalTests           20
# Tests/1M pop         20
# WHO Region            0
# dtype: int64

# %%
# Second method to deal with the missiing values

# Using 'method=ffill' (which is forward fill); means filling missing value with the previous value in the column
# if we check NewCases column 'Nan' replace with the '357.0' 
worldmeter.fillna(method='ffill').head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.310764e+08     3545077       NaN
# 1         Brazil  South America  2.126159e+08     1931204       NaN
# 2          India           Asia  1.380493e+09      937844     357.0
# 3         Russia         Europe  1.459370e+08      739947     357.0
# 4           Peru  South America  3.298745e+07      333867     357.0
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     139143.0        NaN       1600195.0           NaN    1805739.0
# 1      74262.0        NaN       1213512.0           NaN     643430.0
# 2      24327.0       12.0        593178.0          98.0     320339.0
# 3      11614.0       12.0        512825.0          98.0     215508.0
# 4      12229.0       12.0        223261.0          98.0      98377.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           16337.0           10708.0          420.0  44030877.0
# ...

# %%
wmf = worldmeter.fillna(method='ffill').head()

# %%
print (wmf.apply(missing_number, axis=0))
# Out:
# Country/Region      0
# Continent           0
# Population          0
# TotalCases          0
# NewCases            2
# TotalDeaths         0
# NewDeaths           2
# TotalRecovered      0
# NewRecovered        2
# ActiveCases         0
# Serious,Critical    0
# Tot Cases/1M pop    0
# Deaths/1M pop       0
# TotalTests          0
# Tests/1M pop        0
# WHO Region          0
# dtype: int64

# %%
# Third method to deal with the missiing values
wmb = worldmeter.fillna(method='bfill').head()

# %%
print (wmb.apply(missing_number, axis=0))
# Out:
# Country/Region      0
# Continent           0
# Population          0
# TotalCases          0
# NewCases            0
# TotalDeaths         0
# NewDeaths           0
# TotalRecovered      0
# NewRecovered        0
# ActiveCases         0
# Serious,Critical    0
# Tot Cases/1M pop    0
# Deaths/1M pop       0
# TotalTests          0
# Tests/1M pop        0
# WHO Region          0
# dtype: int64

# %% [markdown]
# ### 6) Plotting (Boxplot & Histogram) with Pandas

# %%
sales = pd.read_csv('D:/Python Practice/1. Data Manipulation & Analysis Using Python (Pandad & Matlibplot)/BikeStoresales_data.csv')

# %%
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  11/26/2013   26  November  2013            19     Youth (<25)
# 1  11/26/2015   26  November  2015            19     Youth (<25)
# 2   3/23/2014   23     March  2014            49  Adults (35-64)
# 3   3/23/2016   23     March  2016            49  Adults (35-64)
# 4   5/15/2014   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Alternative Ways to write the Code

# 1) sales.hist(column="Unit_Cost", bins=[1,401,801,1201,1601,2001,2171], figsize=(14,6)) 
# 2) sales['Unit_Cost'].plot(kind='hist',bins=[1,401,801,1201,1601,2001,2171], figsize=(14,6))

sales.hist(column="Unit_Cost", bins=[1,401,801,1201,1601,2001,2171], figsize=(14,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022322F89608>]],
#       dtype=object)

# %%
sales.hist(column="Profit",by="Age_Group",bins=8,figsize=(14,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022322F7EB88>,
# ...
#       dtype=object)

# %%
# Alternative Ways to write the Code
# 1) sales['Unit_Cost'].plot(kind='box', figsize=(14,6)) 
# 2) sales.boxplot(column="Unit_Cost", figsize=(14,6))
sales.boxplot(column="Unit_Cost", figsize=(14,6))

# %%
sales.boxplot(column="Unit_Cost", vert=False, figsize=(14,6))

# %%
sales.boxplot(column="Profit",by="Age_Group", figsize=(14,6))
